# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 599

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
cities[:5]#checking the cities variable
# Out:
# ['sur', 'ginir', 'waitangi', 'ilulissat', 'bethel']

# %%
weather_api_key #checking the api key
# Out:
# '059cc001a7c658700b18e0b9bc5fa219'

# %%
url = "https://api.geoapify.com/v1/geocode/search"
city_url = f"{url}?text={cities[0]}&format=json&apiKey={weather_api_key}"
city_url
weather_url = "https://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key + "&q=" + cities[0]
weather_url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=059cc001a7c658700b18e0b9bc5fa219&q=sur'

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
# url = "https://api.geoapify.com/v1/geocode/search"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url+ "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sur
# Processing Record 2 of Set 1 | ginir
# Processing Record 3 of Set 1 | waitangi
# Processing Record 4 of Set 1 | ilulissat
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | enewetak
# Processing Record 7 of Set 1 | invercargill
# Processing Record 8 of Set 1 | margaret river
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | nadi
# Processing Record 12 of Set 1 | mount pearl
# Processing Record 13 of Set 1 | luderitz
# Processing Record 14 of Set 1 | tanjung selor
# City not found. Skipping...
# Processing Record 15 of Set 1 | blackmans bay
# Processing Record 16 of Set 1 | arthur's town
# City not found. Skipping...
# Processing Record 17 of Set 1 | papatowai
# Processing Record 18 of Set 1 | gisborne
# Processing Record 19 of Set 1 | koulamoutou
# Processing Record 20 of Set 1 | kristiansund
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | college
# Processing Record 23 of Set 1 | bilibino
# Processing Record 24 of Set 1 | port mathurin
# Processing Record 25 of Set 1 | bignona
# Processing Record 26 of Set 1 | arlington
# Processing Record 27 of Set 1 | wailua homesteads
# Processing Record 28 of Set 1 | lihue
# Processing Record 29 of Set 1 | lagdo
# Processing Record 30 of Set 1 | haiku-pauwela
# Processing Record 31 of Set 1 | hawaiian paradise park
# Processing Record 32 of Set 1 | rexburg
# Processing Record 33 of Set 1 | lompoc
# Processing Record 34 of Set 1 | hadibu
# Processing Record 35 of Set 1 | mezgor'e
# City not found. Skipping...
# Processing Record 36 of Set 1 | salug
# Processing Record 37 of Set 1 | horta
# Processing Record 38 of Set 1 | edinburgh of the seven seas
# Processing Record 39 of Set 1 | hailar
# Processing Record 40 of Set 1 | constantia
# Processing Record 41 of Set 1 | minas de matahambre
# City not found. Skipping...
# Processing Record 42 of Set 1 | grytviken
# Processing Record 43 of Set 1 | keflavik
# Processing Record 44 of Set 1 | masterton
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | touggourt
# Processing Record 47 of Set 1 | vernon
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | cabedelo
# Processing Record 50 of Set 1 | adamstown
# Processing Record 0 of Set 2 | vakarai
# Processing Record 1 of Set 2 | pacific grove
# Processing Record 2 of Set 2 | mirnyy
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | port augusta
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | tazovsky
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | siguatepeque
# Processing Record 9 of Set 2 | asind
# Processing Record 10 of Set 2 | chonchi
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | alaghsas
# Processing Record 13 of Set 2 | paracale
# Processing Record 14 of Set 2 | iskateley
# Processing Record 15 of Set 2 | san patricio
# Processing Record 16 of Set 2 | san luis de la loma
# Processing Record 17 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 18 of Set 2 | tulagi
# Processing Record 19 of Set 2 | puerto natales
# Processing Record 20 of Set 2 | prince rupert
# Processing Record 21 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 22 of Set 2 | khorramabad
# Processing Record 23 of Set 2 | coalcoman de vazquez pallares
# Processing Record 24 of Set 2 | melekeok village
# Processing Record 25 of Set 2 | olonkinbyen
# Processing Record 26 of Set 2 | minas de marcona
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | kolondieba
# Processing Record 29 of Set 2 | naivasha
# Processing Record 30 of Set 2 | port douglas
# Processing Record 31 of Set 2 | vrangel'
# Processing Record 32 of Set 2 | dudinka
# Processing Record 33 of Set 2 | barra de santo antonio
# Processing Record 34 of Set 2 | ushuaia
# Processing Record 35 of Set 2 | zeya
# Processing Record 36 of Set 2 | longyearbyen
# Processing Record 37 of Set 2 | la'ie
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | suva
# Processing Record 40 of Set 2 | vorgashor
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | ambodifotatra
# Processing Record 43 of Set 2 | jayapura
# Processing Record 44 of Set 2 | whitehorse
# Processing Record 45 of Set 2 | qaqortoq
# Processing Record 46 of Set 2 | paros
# Processing Record 47 of Set 2 | kiunga
# Processing Record 48 of Set 2 | camocim
# Processing Record 49 of Set 2 | talnakh
# Processing Record 0 of Set 3 | nanzhou
# Processing Record 1 of Set 3 | tidjikja
# Processing Record 2 of Set 3 | severo-yeniseyskiy
# Processing Record 3 of Set 3 | port saint john's
# Processing Record 4 of Set 3 | porto novo
# Processing Record 5 of Set 3 | agat village
# Processing Record 6 of Set 3 | rancharia
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | sitka
# Processing Record 9 of Set 3 | vorkuta
# Processing Record 10 of Set 3 | huruta
# Processing Record 11 of Set 3 | el calafate
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | vila velha
# Processing Record 14 of Set 3 | bayanhongor
# Processing Record 15 of Set 3 | madang
# Processing Record 16 of Set 3 | dakhla
# Processing Record 17 of Set 3 | beteza
# City not found. Skipping...
# Processing Record 18 of Set 3 | ironwood
# Processing Record 19 of Set 3 | ba
# City not found. Skipping...
# Processing Record 20 of Set 3 | udachny
# Processing Record 21 of Set 3 | poltavka
# Processing Record 22 of Set 3 | jiangyou
# Processing Record 23 of Set 3 | hobyo
# Processing Record 24 of Set 3 | codrington
# Processing Record 25 of Set 3 | port alberni
# Processing Record 26 of Set 3 | tolanaro
# Processing Record 27 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | stanley
# Processing Record 30 of Set 3 | weno
# Processing Record 31 of Set 3 | wuyang
# Processing Record 32 of Set 3 | carutapera
# Processing Record 33 of Set 3 | buala
# Processing Record 34 of Set 3 | quellon
# Processing Record 35 of Set 3 | sultanpur
# Processing Record 36 of Set 3 | parras de la fuente
# Processing Record 37 of Set 3 | antofagasta
# Processing Record 38 of Set 3 | aomori
# Processing Record 39 of Set 3 | puerto baquerizo moreno
# Processing Record 40 of Set 3 | ha tinh
# Processing Record 41 of Set 3 | ulladulla
# Processing Record 42 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 43 of Set 3 | gadzhiyevo
# Processing Record 44 of Set 3 | punta arenas
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 3 | murzuq
# Processing Record 48 of Set 3 | ust-nera
# Processing Record 49 of Set 3 | wajir
# Processing Record 0 of Set 4 | butia
# Processing Record 1 of Set 4 | malpica
# Processing Record 2 of Set 4 | anadyr
# Processing Record 3 of Set 4 | arcos
# Processing Record 4 of Set 4 | san miguel
# Processing Record 5 of Set 4 | mariehamn
# Processing Record 6 of Set 4 | nyurba
# Processing Record 7 of Set 4 | huangshan
# Processing Record 8 of Set 4 | dawesville
# Processing Record 9 of Set 4 | sukhodol
# Processing Record 10 of Set 4 | atafu village
# Processing Record 11 of Set 4 | kuje
# Processing Record 12 of Set 4 | huarmey
# Processing Record 13 of Set 4 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 14 of Set 4 | manado
# Processing Record 15 of Set 4 | antigonish
# Processing Record 16 of Set 4 | richards bay
# Processing Record 17 of Set 4 | willowmore
# Processing Record 18 of Set 4 | fort bragg
# Processing Record 19 of Set 4 | mandelieu-la-napoule
# Processing Record 20 of Set 4 | piacabucu
# Processing Record 21 of Set 4 | west island
# Processing Record 22 of Set 4 | sechura
# Processing Record 23 of Set 4 | povoa de santa iria
# Processing Record 24 of Set 4 | badger
# Processing Record 25 of Set 4 | buckie
# Processing Record 26 of Set 4 | nalut
# Processing Record 27 of Set 4 | st. john's
# Processing Record 28 of Set 4 | borgarnes
# Processing Record 29 of Set 4 | balasore
# Processing Record 30 of Set 4 | walvis bay
# Processing Record 31 of Set 4 | alpena
# Processing Record 32 of Set 4 | ta`u
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | sonsorol village
# City not found. Skipping...
# Processing Record 35 of Set 4 | kingston
# Processing Record 36 of Set 4 | moss vale
# Processing Record 37 of Set 4 | ascension
# Processing Record 38 of Set 4 | mount isa
# Processing Record 39 of Set 4 | zemio
# Processing Record 40 of Set 4 | labasa
# Processing Record 41 of Set 4 | fort mcmurray
# Processing Record 42 of Set 4 | jeddah
# Processing Record 43 of Set 4 | yangambi
# Processing Record 44 of Set 4 | margate
# Processing Record 45 of Set 4 | hermanus
# Processing Record 46 of Set 4 | pirassununga
# Processing Record 47 of Set 4 | okondja
# Processing Record 48 of Set 4 | fernie
# Processing Record 49 of Set 4 | novyy urengoy
# Processing Record 0 of Set 5 | fale old settlement
# Processing Record 1 of Set 5 | tsiombe
# Processing Record 2 of Set 5 | klyuchi
# Processing Record 3 of Set 5 | porto velho
# Processing Record 4 of Set 5 | cockburn town
# Processing Record 5 of Set 5 | halmstad
# Processing Record 6 of Set 5 | kyzylorda
# Processing Record 7 of Set 5 | kiato
# Processing Record 8 of Set 5 | lobujya
# Processing Record 9 of Set 5 | isafjordur
# Processing Record 10 of Set 5 | palmer
# Processing Record 11 of Set 5 | paka
# Processing Record 12 of Set 5 | mogocha
# Processing Record 13 of Set 5 | vadso
# Processing Record 14 of Set 5 | florenville
# Processing Record 15 of Set 5 | hugo
# Processing Record 16 of Set 5 | fortaleza
# Processing Record 17 of Set 5 | petauke
# Processing Record 18 of Set 5 | new norfolk
# Processing Record 19 of Set 5 | cannonvale
# Processing Record 20 of Set 5 | wuchuan
# Processing Record 21 of Set 5 | bukittinggi
# Processing Record 22 of Set 5 | olinda
# Processing Record 23 of Set 5 | marshall
# Processing Record 24 of Set 5 | mejit
# Processing Record 25 of Set 5 | kodiak
# Processing Record 26 of Set 5 | holualoa
# Processing Record 27 of Set 5 | praia da vitoria
# Processing Record 28 of Set 5 | sinabang
# Processing Record 29 of Set 5 | shimoda
# Processing Record 30 of Set 5 | geraldton
# Processing Record 31 of Set 5 | acapulco de juarez
# Processing Record 32 of Set 5 | peterhead
# Processing Record 33 of Set 5 | kitimat
# Processing Record 34 of Set 5 | raja
# Processing Record 35 of Set 5 | nam som
# Processing Record 36 of Set 5 | allen
# Processing Record 37 of Set 5 | nova vicosa
# Processing Record 38 of Set 5 | mau
# Processing Record 39 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 40 of Set 5 | nantucket
# Processing Record 41 of Set 5 | igarka
# Processing Record 42 of Set 5 | mil'kovo
# Processing Record 43 of Set 5 | puerto colombia
# Processing Record 44 of Set 5 | kresttsy
# Processing Record 45 of Set 5 | kruisfontein
# Processing Record 46 of Set 5 | kendari
# Processing Record 47 of Set 5 | bodo
# Processing Record 48 of Set 5 | camana
# Processing Record 49 of Set 5 | salah bey
# Processing Record 0 of Set 6 | antalaha
# Processing Record 1 of Set 6 | jalai nur
# Processing Record 2 of Set 6 | broken hill
# Processing Record 3 of Set 6 | port alfred
# Processing Record 4 of Set 6 | ashburton
# Processing Record 5 of Set 6 | dauphin
# Processing Record 6 of Set 6 | buwenge
# Processing Record 7 of Set 6 | norderney
# Processing Record 8 of Set 6 | hasaki
# Processing Record 9 of Set 6 | santa vitoria do palmar
# Processing Record 10 of Set 6 | kharp
# Processing Record 11 of Set 6 | namibe
# Processing Record 12 of Set 6 | laguna
# Processing Record 13 of Set 6 | puerto montt
# Processing Record 14 of Set 6 | parral
# Processing Record 15 of Set 6 | mbanza-ngungu
# Processing Record 16 of Set 6 | dalandzadgad
# Processing Record 17 of Set 6 | kinablangan
# Processing Record 18 of Set 6 | vohipaho
# City not found. Skipping...
# Processing Record 19 of Set 6 | tralee
# Processing Record 20 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 21 of Set 6 | utrik
# Processing Record 22 of Set 6 | howard springs
# Processing Record 23 of Set 6 | klaksvik
# Processing Record 24 of Set 6 | bazpur
# Processing Record 25 of Set 6 | turbat
# Processing Record 26 of Set 6 | chilca
# Processing Record 27 of Set 6 | malanje
# Processing Record 28 of Set 6 | tambacounda
# Processing Record 29 of Set 6 | quang ngai
# Processing Record 30 of Set 6 | east london
# Processing Record 31 of Set 6 | gagliano del capo
# Processing Record 32 of Set 6 | san fernando de apure
# Processing Record 33 of Set 6 | sao joao da barra
# Processing Record 34 of Set 6 | 'ali al gharbi
# Processing Record 35 of Set 6 | conduaga
# Processing Record 36 of Set 6 | onverwacht
# Processing Record 37 of Set 6 | santa cruz
# Processing Record 38 of Set 6 | susuman
# Processing Record 39 of Set 6 | pokhara
# Processing Record 40 of Set 6 | santana
# Processing Record 41 of Set 6 | swift current
# Processing Record 42 of Set 6 | kerikeri
# Processing Record 43 of Set 6 | sandnessjoen
# Processing Record 44 of Set 6 | juneau
# Processing Record 45 of Set 6 | puerto aysen
# Processing Record 46 of Set 6 | rio grande
# Processing Record 47 of Set 6 | bahar
# Processing Record 48 of Set 6 | byron bay
# Processing Record 49 of Set 6 | olyokminsk
# Processing Record 0 of Set 7 | tsumeb
# Processing Record 1 of Set 7 | fukuecho
# Processing Record 2 of Set 7 | cabo san lucas
# Processing Record 3 of Set 7 | zambezi
# Processing Record 4 of Set 7 | monrovia
# Processing Record 5 of Set 7 | qamdo
# Processing Record 6 of Set 7 | borzya
# Processing Record 7 of Set 7 | san-pedro
# Processing Record 8 of Set 7 | guaraniacu
# Processing Record 9 of Set 7 | ocos
# Processing Record 10 of Set 7 | wynyard
# Processing Record 11 of Set 7 | saint-joseph
# Processing Record 12 of Set 7 | middlebury (village)
# Processing Record 13 of Set 7 | westport
# Processing Record 14 of Set 7 | sisimiut
# Processing Record 15 of Set 7 | kralendijk
# Processing Record 16 of Set 7 | miyaly
# Processing Record 17 of Set 7 | gamay
# Processing Record 18 of Set 7 | zaozersk
# Processing Record 19 of Set 7 | carloforte
# Processing Record 20 of Set 7 | lorengau
# Processing Record 21 of Set 7 | la sarre
# Processing Record 22 of Set 7 | mirny
# Processing Record 23 of Set 7 | langepas
# Processing Record 24 of Set 7 | aasiaat
# Processing Record 25 of Set 7 | tindouf
# Processing Record 26 of Set 7 | esmeraldas
# Processing Record 27 of Set 7 | saint-francois
# Processing Record 28 of Set 7 | fuerte olimpo
# Processing Record 29 of Set 7 | sanming
# Processing Record 30 of Set 7 | puerto morazan
# Processing Record 31 of Set 7 | mutuali
# Processing Record 32 of Set 7 | mantua
# Processing Record 33 of Set 7 | la passe
# Processing Record 34 of Set 7 | yel'nya
# Processing Record 35 of Set 7 | tura
# Processing Record 36 of Set 7 | codajas
# Processing Record 37 of Set 7 | nadym
# Processing Record 38 of Set 7 | colonia menno
# Processing Record 39 of Set 7 | afaahiti
# Processing Record 40 of Set 7 | bridgewater
# Processing Record 41 of Set 7 | kupang
# Processing Record 42 of Set 7 | floro
# Processing Record 43 of Set 7 | happy valley-goose bay
# Processing Record 44 of Set 7 | queenstown
# Processing Record 45 of Set 7 | clinton
# Processing Record 46 of Set 7 | cururupu
# Processing Record 47 of Set 7 | nelson bay
# Processing Record 48 of Set 7 | ha'il
# Processing Record 49 of Set 7 | lazaro cardenas
# Processing Record 0 of Set 8 | narsinghgarh
# Processing Record 1 of Set 8 | cam ranh
# Processing Record 2 of Set 8 | rudnyy
# Processing Record 3 of Set 8 | kapiri mposhi
# Processing Record 4 of Set 8 | machala
# Processing Record 5 of Set 8 | basse-terre
# Processing Record 6 of Set 8 | revda
# Processing Record 7 of Set 8 | shingu
# Processing Record 8 of Set 8 | buka
# Processing Record 9 of Set 8 | roanoke
# Processing Record 10 of Set 8 | katsuura
# Processing Record 11 of Set 8 | san antonio de pale
# Processing Record 12 of Set 8 | santa elena de uairen
# Processing Record 13 of Set 8 | petrovsk-zabaykal'skiy
# Processing Record 14 of Set 8 | labrador city
# Processing Record 15 of Set 8 | pasighat
# Processing Record 16 of Set 8 | banting
# Processing Record 17 of Set 8 | egilsstadir
# Processing Record 18 of Set 8 | altai
# Processing Record 19 of Set 8 | lodja
# Processing Record 20 of Set 8 | deyang
# Processing Record 21 of Set 8 | robore
# Processing Record 22 of Set 8 | kone
# Processing Record 23 of Set 8 | abraham's bay
# City not found. Skipping...
# Processing Record 24 of Set 8 | bandarbeyla
# Processing Record 25 of Set 8 | kenai
# Processing Record 26 of Set 8 | marka
# Processing Record 27 of Set 8 | kirundo
# Processing Record 28 of Set 8 | al qusayr
# Processing Record 29 of Set 8 | sale
# Processing Record 30 of Set 8 | tazacorte
# Processing Record 31 of Set 8 | bokovskaya
# Processing Record 32 of Set 8 | kununurra
# Processing Record 33 of Set 8 | saynshand
# Processing Record 34 of Set 8 | burela de cabo
# Processing Record 35 of Set 8 | dompu
# Processing Record 36 of Set 8 | lewiston orchards
# Processing Record 37 of Set 8 | road town
# Processing Record 38 of Set 8 | boden
# Processing Record 39 of Set 8 | guerrero negro
# Processing Record 40 of Set 8 | sao paulo de olivenca
# Processing Record 41 of Set 8 | babol
# Processing Record 42 of Set 8 | huanuni
# Processing Record 43 of Set 8 | flin flon
# Processing Record 44 of Set 8 | cole harbour
# Processing Record 45 of Set 8 | paola
# Processing Record 46 of Set 8 | lata
# Processing Record 47 of Set 8 | ijuw
# City not found. Skipping...
# Processing Record 48 of Set 8 | jiuquan
# Processing Record 49 of Set 8 | salinopolis
# Processing Record 0 of Set 9 | hamilton
# Processing Record 1 of Set 9 | kapuskasing
# Processing Record 2 of Set 9 | uturoa
# Processing Record 3 of Set 9 | vettur
# City not found. Skipping...
# Processing Record 4 of Set 9 | fedorovskiy
# Processing Record 5 of Set 9 | taybad
# Processing Record 6 of Set 9 | massawa
# Processing Record 7 of Set 9 | shohimardon
# Processing Record 8 of Set 9 | palora
# Processing Record 9 of Set 9 | bargaal
# Processing Record 10 of Set 9 | ndende
# Processing Record 11 of Set 9 | saipan
# Processing Record 12 of Set 9 | lebanon
# Processing Record 13 of Set 9 | ryotsu-minato
# Processing Record 14 of Set 9 | encruzilhada do sul
# Processing Record 15 of Set 9 | conception bay south
# Processing Record 16 of Set 9 | galeana
# Processing Record 17 of Set 9 | manicore
# Processing Record 18 of Set 9 | iwon-up
# Processing Record 19 of Set 9 | morehead city
# Processing Record 20 of Set 9 | huangnihe
# Processing Record 21 of Set 9 | kudahuvadhoo
# Processing Record 22 of Set 9 | miri
# Processing Record 23 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 24 of Set 9 | qobustan
# Processing Record 25 of Set 9 | puerto leguizamo
# Processing Record 26 of Set 9 | manatutu
# City not found. Skipping...
# Processing Record 27 of Set 9 | eilat
# Processing Record 28 of Set 9 | porto murtinho
# Processing Record 29 of Set 9 | n'zeto
# Processing Record 30 of Set 9 | polyarnyy
# Processing Record 31 of Set 9 | remire-montjoly
# Processing Record 32 of Set 9 | ghat
# Processing Record 33 of Set 9 | mendoza
# Processing Record 34 of Set 9 | mount gambier
# Processing Record 35 of Set 9 | laojunmiao
# Processing Record 36 of Set 9 | port hedland
# Processing Record 37 of Set 9 | la ronge
# Processing Record 38 of Set 9 | nemuro
# Processing Record 39 of Set 9 | urucui
# Processing Record 40 of Set 9 | banamba
# Processing Record 41 of Set 9 | parang
# Processing Record 42 of Set 9 | el coacoyul
# Processing Record 43 of Set 9 | nizhnesortymskiy
# Processing Record 44 of Set 9 | benguela
# Processing Record 45 of Set 9 | tarfaya
# Processing Record 46 of Set 9 | dara
# Processing Record 47 of Set 9 | thayetmyo
# Processing Record 48 of Set 9 | nenjiang
# Processing Record 49 of Set 9 | priladozhskiy
# Processing Record 0 of Set 10 | rundu
# Processing Record 1 of Set 10 | tuntum
# Processing Record 2 of Set 10 | boras
# Processing Record 3 of Set 10 | erenhot
# Processing Record 4 of Set 10 | taltal
# Processing Record 5 of Set 10 | weyburn
# Processing Record 6 of Set 10 | st. paul
# Processing Record 7 of Set 10 | hilo
# Processing Record 8 of Set 10 | quibdo
# Processing Record 9 of Set 10 | laem sing
# Processing Record 10 of Set 10 | island harbour
# Processing Record 11 of Set 10 | kaa-khem
# Processing Record 12 of Set 10 | uzgen
# Processing Record 13 of Set 10 | glace bay
# Processing Record 14 of Set 10 | cootamundra
# Processing Record 15 of Set 10 | maria aurora
# Processing Record 16 of Set 10 | heihe
# Processing Record 17 of Set 10 | lerwick
# Processing Record 18 of Set 10 | tannum sands
# Processing Record 19 of Set 10 | hami
# Processing Record 20 of Set 10 | decatur
# Processing Record 21 of Set 10 | port-vila
# Processing Record 22 of Set 10 | terrace
# Processing Record 23 of Set 10 | zhigalovo
# Processing Record 24 of Set 10 | swan hill
# Processing Record 25 of Set 10 | vidyayevo
# Processing Record 26 of Set 10 | box elder
# Processing Record 27 of Set 10 | galliano
# Processing Record 28 of Set 10 | dondo
# Processing Record 29 of Set 10 | blackfoot
# Processing Record 30 of Set 10 | fisterra
# Processing Record 31 of Set 10 | kalmunai
# Processing Record 32 of Set 10 | retreat
# Processing Record 33 of Set 10 | magadan
# Processing Record 34 of Set 10 | al burayqah
# Processing Record 35 of Set 10 | emerald
# Processing Record 36 of Set 10 | bardai
# Processing Record 37 of Set 10 | zermatt
# Processing Record 38 of Set 10 | santa terezinha
# Processing Record 39 of Set 10 | boa vista
# Processing Record 40 of Set 10 | taoudenni
# Processing Record 41 of Set 10 | eyl
# Processing Record 42 of Set 10 | kolonia
# Processing Record 43 of Set 10 | shenjiamen
# Processing Record 44 of Set 10 | higuera de zaragoza
# Processing Record 45 of Set 10 | chibougamau
# Processing Record 46 of Set 10 | pyhajarvi
# Processing Record 47 of Set 10 | simao dias
# Processing Record 48 of Set 10 | san juan de los morros
# Processing Record 49 of Set 10 | al qusiyah
# Processing Record 0 of Set 11 | esbjerg
# Processing Record 1 of Set 11 | belmonte
# Processing Record 2 of Set 11 | gilgit
# Processing Record 3 of Set 11 | antonio enes
# Processing Record 4 of Set 11 | fayetteville
# Processing Record 5 of Set 11 | akureyri
# Processing Record 6 of Set 11 | xinyuan
# Processing Record 7 of Set 11 | lahij
# Processing Record 8 of Set 11 | bouca
# Processing Record 9 of Set 11 | west end village
# City not found. Skipping...
# Processing Record 10 of Set 11 | tosontsengel
# Processing Record 11 of Set 11 | vilyuchinsk
# Processing Record 12 of Set 11 | kapa'a
# Processing Record 13 of Set 11 | selfoss
# Processing Record 14 of Set 11 | newman
# Processing Record 15 of Set 11 | petrozavodsk
# Processing Record 16 of Set 11 | lamarque
# Processing Record 17 of Set 11 | korla
# Processing Record 18 of Set 11 | murghob
# Processing Record 19 of Set 11 | dunda
# Processing Record 20 of Set 11 | daulatpur
# Processing Record 21 of Set 11 | tshikapa
# Processing Record 22 of Set 11 | dunedin
# Processing Record 23 of Set 11 | nizhneudinsk
# Processing Record 24 of Set 11 | keren
# Processing Record 25 of Set 11 | korsakov
# Processing Record 26 of Set 11 | greenville
# Processing Record 27 of Set 11 | mahibadhoo
# Processing Record 28 of Set 11 | muravlenko
# Processing Record 29 of Set 11 | tongliao
# Processing Record 30 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 31 of Set 11 | bereznehuvate
# Processing Record 32 of Set 11 | taulaga
# Processing Record 33 of Set 11 | ixtapa
# Processing Record 34 of Set 11 | pandan
# Processing Record 35 of Set 11 | palembang
# Processing Record 36 of Set 11 | aripuana
# Processing Record 37 of Set 11 | ventspils
# Processing Record 38 of Set 11 | gueltat zemmour
# City not found. Skipping...
# Processing Record 39 of Set 11 | la dorada
# Processing Record 40 of Set 11 | les sables-d'olonne
# Processing Record 41 of Set 11 | chos malal
# Processing Record 42 of Set 11 | ippy
# Processing Record 43 of Set 11 | fada
# Processing Record 44 of Set 11 | santa ana
# Processing Record 45 of Set 11 | zhangjiakou
# Processing Record 46 of Set 11 | furukawa
# Processing Record 47 of Set 11 | markovo
# Processing Record 48 of Set 11 | vanino
# Processing Record 49 of Set 11 | saudarkrokur
# Processing Record 0 of Set 12 | kirensk
# Processing Record 1 of Set 12 | nawanshahr
# Processing Record 2 of Set 12 | campbellton
# Processing Record 3 of Set 12 | red hill
# Processing Record 4 of Set 12 | ilha de mocambique
# Processing Record 5 of Set 12 | zunyi
# Processing Record 6 of Set 12 | wuchang
# Processing Record 7 of Set 12 | lhuentse
# Processing Record 8 of Set 12 | saint-philippe
# Processing Record 9 of Set 12 | kodok
# City not found. Skipping...
# Processing Record 10 of Set 12 | ortona
# Processing Record 11 of Set 12 | namdrik
# Processing Record 12 of Set 12 | ifakara
# Processing Record 13 of Set 12 | corning
# Processing Record 14 of Set 12 | satkhira
# Processing Record 15 of Set 12 | umaria
# Processing Record 16 of Set 12 | nema
# Processing Record 17 of Set 12 | tulun
# Processing Record 18 of Set 12 | nevesinje
# Processing Record 19 of Set 12 | la reforma
# Processing Record 20 of Set 12 | labuan lombok
# City not found. Skipping...
# Processing Record 21 of Set 12 | changli
# Processing Record 22 of Set 12 | yuzhno-kurilsk
# Processing Record 23 of Set 12 | the dalles
# Processing Record 24 of Set 12 | koulikoro
# Processing Record 25 of Set 12 | north bend
# Processing Record 26 of Set 12 | bucerias
# Processing Record 27 of Set 12 | poronaysk
# Processing Record 28 of Set 12 | turkmenabat
# Processing Record 29 of Set 12 | merta
# Processing Record 30 of Set 12 | sao miguel do araguaia
# Processing Record 31 of Set 12 | orbetello
# Processing Record 32 of Set 12 | vila franca do campo
# Processing Record 33 of Set 12 | port lincoln
# Processing Record 34 of Set 12 | puerto armuelles
# Processing Record 35 of Set 12 | sucre
# Processing Record 36 of Set 12 | shubarshi
# Processing Record 37 of Set 12 | i-n-salah
# Processing Record 38 of Set 12 | tank
# Processing Record 39 of Set 12 | berdigestyakh
# Processing Record 40 of Set 12 | vilyuysk
# Processing Record 41 of Set 12 | pitimbu
# Processing Record 42 of Set 12 | aroma
# Processing Record 43 of Set 12 | pierre
# Processing Record 44 of Set 12 | mocimboa
# Processing Record 45 of Set 12 | luanda
# Processing Record 46 of Set 12 | natal
# Processing Record 47 of Set 12 | maintirano
# Processing Record 48 of Set 12 | barcelona
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              sur  22.5667   59.5289     28.55        57          32
# 1            ginir   7.1333   40.7000     16.63        81           5
# 2         waitangi -43.9535 -176.5597     16.57        91          33
# 3        ilulissat  69.2167  -51.1000     -6.99        73          40
# 4           bethel  41.3712  -73.4140     24.64        32           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.82      OM  1712694979
# 1              1.63      ET  1712694979
# 2              3.58      NZ  1712694979
# 3              2.06      GL  1712694980
# 4              2.57      US  1712694980

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              sur  22.5667   59.5289     28.55        57          32
# 1            ginir   7.1333   40.7000     16.63        81           5
# 2         waitangi -43.9535 -176.5597     16.57        91          33
# 3        ilulissat  69.2167  -51.1000     -6.99        73          40
# 4           bethel  41.3712  -73.4140     24.64        32           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.82      OM  1712694979
# 1              1.63      ET  1712694979
# 2              3.58      NZ  1712694979
# 3              2.06      GL  1712694980
# 4              2.57      US  1712694980

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black", alpha=0.75)


# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (01/01/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

#os.makedirs("output_data", exist_ok=True)

# Save the figure
#plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black", alpha=0.75)


# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (01/01/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)


# Save the figure
#plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black", alpha=0.75)


# Incorporate the other graph properties

plt.title("City Latitude vs. Cloudiness (01/01/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
#plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black", alpha=0.75)


# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (01/01/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)


# Save the figure
#plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, x_label, y_label, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]


# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              sur  22.5667   59.5289     28.55        57          32
# 1            ginir   7.1333   40.7000     16.63        81           5
# 3        ilulissat  69.2167  -51.1000     -6.99        73          40
# 4           bethel  41.3712  -73.4140     24.64        32           0
# 5         enewetak  11.3474  162.3373     27.16        80         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.82      OM  1712694979
# 1              1.63      ET  1712694979
# 3              2.06      GL  1712694980
# 4              2.57      US  1712694980
# 5              9.87      MH  1712694980

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]


# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                 waitangi -43.9535 -176.5597     16.57        91          33
# 6             invercargill -46.4000  168.3500     12.79        95         100
# 7           margaret river -33.9500  115.0667     12.74        80          30
# 9        port-aux-francais -49.3500   70.2167      8.54        94         100
# 10                    nadi -17.8000  177.4167     28.00        78          40
#
#          Wind Speed Country        Date
# City_ID
# 2              3.58      NZ  1712694979
# 6              1.79      NZ  1712694980
# 7              5.56      AU  1712694981
# 9             17.02      TF  1712694981
# 10             0.00      FJ  1712694827

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Extract the variables for the linear regression
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Plot linear regression on top of scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Annotate the line equation on the plot
plt.annotate(line_eq,(0,20),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')

# Show plot
plt.show()
# Out:
# The r-squared is: 0.6796067766796307

# %%
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                 waitangi -43.9535 -176.5597     16.57        91          33
# 6             invercargill -46.4000  168.3500     12.79        95         100
# 7           margaret river -33.9500  115.0667     12.74        80          30
# 9        port-aux-francais -49.3500   70.2167      8.54        94         100
# 10                    nadi -17.8000  177.4167     28.00        78          40
#
#          Wind Speed Country        Date
# City_ID
# 2              3.58      NZ  1712694979
# 6              1.79      NZ  1712694980
# 7              5.56      AU  1712694981
# 9             17.02      TF  1712694981
# 10             0.00      FJ  1712694827

# %%
# Linear regression on Southern Hemisphere
# Extract the variables for the linear regression
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Plot linear regression on top of scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Annotate the line equation on the plot
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')

# Show plot
plt.show()
# Out:
# The r-squared is: 0.5749180740195594

# %% [markdown]
# **Discussion about the linear relationship:** In this regression a direct correlation is shown between the distance further from the equator in either direction the colder it gets. Both r-square values show a good correlation between data sets.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Extract the variables for the linear regression
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Plot linear regression on top of scatter plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Annotate the line equation on the plot
plt.annotate(line_eq, (0, 20), fontsize=15, color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression')

# Show plot
plt.show()
# Out:
# The r-squared is: 0.06939321817285987

# %%
# Southern Hemisphere
# Extract the variables for the linear regression
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Plot linear regression on top of scatter plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Annotate the line equation on the plot
plt.annotate(line_eq, (-30, 50), fontsize=15, color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')

# Show plot
plt.show()
# Out:
# The r-squared is: 0.04390265873337717

# %% [markdown]
# **Discussion about the linear relationship:** In this regression the further north fron the equator there is a slight increase in humidity, and the further south fron the equator, there is slighter decrease in humidity. Both r-square values show a good correlation between data sets with the north being a bit better.

# %% [markdown]
# Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Extract the variables for the linear regression
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Plot linear regression on top of scatter plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Annotate the line equation on the plot
plt.annotate(line_eq, (0, 20), fontsize=15, color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness vs. Latitude Linear Regression')

# Show plot
plt.show()
# Out:
# The r-squared is: 0.010968928432994414

# %%
# Southern Hemisphere
# Extract the variables for the linear regression
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Plot linear regression on top of scatter plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Annotate the line equation on the plot
plt.annotate(line_eq, (-30, 50), fontsize=15, color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness vs. Latitude Linear Regression')

# Show plot
plt.show()
# Out:
# The r-squared is: 0.023284758304424866

# %% [markdown]
# **Discussion about the linear relationship:** In this linear regression a there is a slight rise in cloudiness the further north and a slight decrease the futther south. Both with low r-square values showing a week correlation between data sets.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Extract the variables for the linear regression
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Plot linear regression on top of scatter plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Annotate the line equation on the plot
plt.annotate(line_eq, (0, 12), fontsize=15, color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression')

# Show plot
plt.show()
# Out:
# The r-squared is: 0.0018595428131058316

# %%
# Southern Hemisphere
# Extract the variables for the linear regression
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Plot linear regression on top of scatter plot
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")

# Annotate the line equation on the plot
plt.annotate(line_eq, (-30, 8), fontsize=15, color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression')

# Show plot
plt.show()
# Out:
# The r-squared is: 0.16007683049223997

# %% [markdown]
# **Discussion about the linear relationship:** This regression shows almost no change the further north and a slight rise the futher south. Both with low r-square values showing a week correlation between data sets.
